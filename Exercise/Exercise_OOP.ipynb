# %% [markdown]
# ### Exercise 01
#
# Implement a class relationship based on the picture below.
# ![Class Relationship Exercise](../img/exercise-class-diagram-01.png)

# %% [markdown]
# ### Exercise 02
#
# Implement a class relationship based on the picture below.
# ![Class Relationship Exercise](../img/exercise-class-diagram-02.png)
